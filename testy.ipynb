# %%
import fungo
from fungo import fangraphs
import pandas as pd

# %%
pitchers = fangraphs.get_leaders(stats="pit", start_season=2025, end_season=2025, qual=100, ind=1)

# %%
pitchers
# Out:
# [{'Throws': 'L',
#   'xMLBAMID': 669373,
#   'Name': '<a href="statss.aspx?playerid=22267&position=P">Tarik Skubal</a>',
#   'Team': '<a href="leaders.aspx?pos=all&stats=pit&lg=all&qual=0&type=strType&season=2025&month=0&season1=2025&ind=1&team=6&rost=0&age=0">DET</a>',
#   'Season': 2025,
#   'Age': 28.0,
#   'AgeR': '28 - 28',
#   'SeasonMin': 2025,
#   'SeasonMax': 2025,
#   'W': 13.0,
#   'L': 6.0,
#   'ERA': 2.2116041531508555,
#   'G': 31.0,
#   'GS': 31.0,
#   'QS': 21.0,
#   'CG': 1.0,
#   'ShO': 1.0,
#   'SV': 0.0,
#   'BS': 0.0,
#   'IP': 195.1,
#   'TBF': 748.0,
#   'H': 141.0,
#   'R': 55.0,
#   'ER': 48.0,
#   'HR': 18.0,
#   'BB': 33.0,
#   'IBB': 0.0,
#   'HBP': 5.0,
#   'WP': 3.0,
#   'BK': 2.0,
#   'SO': 241.0,
#   'GB': 191.0,
#   'FB': 179.0,
#   'LD': 96.0,
#   'IFFB': 21.0,
#   'Pitches': 2849.0,
#   'Balls': 846.0,
#   'Strikes': 2003.0,
#   'RS': 100.0,
#   'IFH': 14.0,
#   'BU': 3.0,
#   'BUH': 2.0,
#   'K/9': 11.104095852278252,
# ...

# %%
pitchers_df = pd.DataFrame(pitchers)

# %%
pitchers_df
# Out:
#     Throws  xMLBAMID                                               Name  \
# 0        L    669373  <a href="statss.aspx?playerid=22267&position=P...
# 1        R    694973  <a href="statss.aspx?playerid=33677&position=P...
# 2        L    650911  <a href="statss.aspx?playerid=20778&position=P...
# 3        L    676979  <a href="statss.aspx?playerid=27463&position=P...
# 4        R    657277  <a href="statss.aspx?playerid=17995&position=P...
# ..     ...       ...                                                ...
# 122      R    607200  <a href="statss.aspx?playerid=17425&position=P...
# 123      L    571760  <a href="statss.aspx?playerid=15423&position=P...
# 124      R    663623  <a href="statss.aspx?playerid=21504&position=P...
# 125      R    621111  <a href="statss.aspx?playerid=19374&position=P...
# 126      R    686799  <a href="statss.aspx?playerid=27688&position=P...
#
#                                                   Team  Season   Age     AgeR  \
# ...

# %%
## piwFA = four seam runs above average 
## FC = cutter, FS = splitter, SI = sinker, CH = changeup, SL = slider, CU = curveball

pitchers_df[['PlayerName', 'sp_stuff', 'Season', 'piwFA', 'piwFC', 'piwFS', 'piwSI', 'piwCH', 'piwSL', 'piwCU']]
# Out:
#              PlayerName    sp_stuff  Season      piwFA     piwFC  piwFS  \
# 0          Tarik Skubal  123.277282    2025   9.815633       NaN    NaN
# 1           Paul Skenes  110.122919    2025  19.082207       NaN    NaN
# 2    Cristopher Sánchez  117.576424    2025        NaN       NaN    NaN
# 3       Garrett Crochet  117.010309    2025  -8.827824  8.652262    NaN
# 4            Logan Webb  105.813242    2025   0.648588 -3.345829    NaN
# ..                  ...         ...     ...        ...       ...    ...
# 122         Erick Fedde   88.509481    2025   0.255742 -8.844628    NaN
# 123       Andrew Heaney   90.188095    2025  -8.973399       NaN    NaN
# 124          Jake Irvin   92.592873    2025 -12.243611  0.879287    NaN
# 125      Walker Buehler   96.087697    2025  -7.042878 -4.000706    NaN
# 126    Jack Kochanowicz   92.528894    2025  -2.645956       NaN    NaN
#
#          piwSI      piwCH      piwSL      piwCU
# 0     5.935200  26.344229   4.162183  -0.203917
# ...
